# %% [markdown]
# <a href="https://colab.research.google.com/github/shankarbalaji124/Day9_ML_codegnan/blob/main/Random_Forest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing the libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Importing the dataset

data  = pd.read_csv("/content/adult.csv")

# %%
#Description and information related to dataset

data.head()
# Out:
#    age          workclass  fnlwgt  ... hours-per-week         country  salary
# 0   39          State-gov   77516  ...             40   United-States   <=50K
# 1   50   Self-emp-not-inc   83311  ...             13   United-States   <=50K
# 2   38            Private  215646  ...             40   United-States   <=50K
# 3   53            Private  234721  ...             40   United-States   <=50K
# 4   28            Private  338409  ...             40            Cuba   <=50K
#
# [5 rows x 15 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  country         32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
data.shape
# Out:
# (32561, 15)

# %%
data.describe()
# Out:
#                 age        fnlwgt  ...  capital-loss  hours-per-week
# count  32561.000000  3.256100e+04  ...  32561.000000    32561.000000
# mean      38.581647  1.897784e+05  ...     87.303830       40.437456
# std       13.640433  1.055500e+05  ...    402.960219       12.347429
# min       17.000000  1.228500e+04  ...      0.000000        1.000000
# 25%       28.000000  1.178270e+05  ...      0.000000       40.000000
# 50%       37.000000  1.783560e+05  ...      0.000000       40.000000
# 75%       48.000000  2.370510e+05  ...      0.000000       45.000000
# max       90.000000  1.484705e+06  ...   4356.000000       99.000000
#
# [8 rows x 6 columns]

# %%
#Check for the null variables

data.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# country           0
# salary            0
# dtype: int64

# %%
#check the age distribution in the dataset using distplot

sns.distplot(data['age'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#Boxplot

sns.boxplot(x = "salary", y= "age", hue = 'sex', data = data)

# %%
data['workclass'].value_counts()
# Out:
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1298
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: workclass, dtype: int64

# %%
data['workclass'] = data['workclass'].replace('?', 'Unknown')

# %%
data.head(60)
# Out:
#     age workclass  fnlwgt  ... hours-per-week         country  salary
# 0    39      None   77516  ...             40   United-States   <=50K
# 1    50      None   83311  ...             13   United-States   <=50K
# 2    38      None  215646  ...             40   United-States   <=50K
# 3    53      None  234721  ...             40   United-States   <=50K
# 4    28      None  338409  ...             40            Cuba   <=50K
# 5    37      None  284582  ...             40   United-States   <=50K
# 6    49      None  160187  ...             16         Jamaica   <=50K
# 7    52      None  209642  ...             45   United-States    >50K
# 8    31      None   45781  ...             50   United-States    >50K
# 9    42      None  159449  ...             40   United-States    >50K
# 10   37      None  280464  ...             80   United-States    >50K
# 11   30      None  141297  ...             40           India    >50K
# 12   23      None  122272  ...             30   United-States   <=50K
# 13   32      None  205019  ...             50   United-States   <=50K
# 14   40      None  121772  ...             40               ?    >50K
# 15   34      None  245487  ...             45          Mexico   <=50K
# 16   25      None  176756  ...             35   United-States   <=50K
# 17   32      None  186824  ...             40   United-States   <=50K
# 18   38      None   28887  ...             50   United-States   <=50K
# 19   43      None  292175  ...             45   United-States    >50K
# 20   40      None  193524  ...             60   United-States    >50K
# 21   54      None  302146  ...             20   United-States   <=50K
# 22   35      None   76845  ...             40   United-States   <=50K
# 23   43      None  117037  ...             40   United-States   <=50K
# 24   59      None  109015  ...             40   United-States   <=50K
# 25   56      None  216851  ...             40   United-States    >50K
# 26   19      None  168294  ...             40   United-States   <=50K
# 27   54      None  180211  ...             60           South    >50K
# 28   39      None  367260  ...             80   United-States   <=50K
# 29   49      None  193366  ...             40   United-States   <=50K
# 30   23      None  190709  ...             52   United-States   <=50K
# 31   20      None  266015  ...             44   United-States   <=50K
# 32   45      None  386940  ...             40   United-States   <=50K
# 33   30      None   59951  ...             40   United-States   <=50K
# 34   22      None  311512  ...             15   United-States   <=50K
# 35   48      None  242406  ...             40     Puerto-Rico   <=50K
# 36   21      None  197200  ...             40   United-States   <=50K
# 37   19      None  544091  ...             25   United-States   <=50K
# 38   31      None   84154  ...             38               ?    >50K
# 39   48      None  265477  ...             40   United-States   <=50K
# 40   31      None  507875  ...             43   United-States   <=50K
# 41   53      None   88506  ...             40   United-States   <=50K
# 42   24      None  172987  ...             50   United-States   <=50K
# 43   49      None   94638  ...             40   United-States   <=50K
# 44   25      None  289980  ...             35   United-States   <=50K
# 45   57      None  337895  ...             40   United-States    >50K
# 46   53      None  144361  ...             38   United-States   <=50K
# 47   44      None  128354  ...             40   United-States   <=50K
# 48   41      None  101603  ...             40   United-States   <=50K
# 49   29      None  271466  ...             43   United-States   <=50K
# 50   25      None   32275  ...             40   United-States   <=50K
# 51   18      None  226956  ...             30               ?   <=50K
# 52   47      None   51835  ...             60        Honduras    >50K
# 53   50      None  251585  ...             55   United-States    >50K
# 54   47      None  109832  ...             60   United-States   <=50K
# 55   43      None  237993  ...             40   United-States    >50K
# 56   46      None  216666  ...             40          Mexico   <=50K
# 57   35      None   56352  ...             40     Puerto-Rico   <=50K
# 58   41      None  147372  ...             48   United-States   <=50K
# 59   30      None  188146  ...             40   United-States   <=50K
#
# [60 rows x 15 columns]

# %%
data['workclass'].value_counts()
# Out:
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1298
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: workclass, dtype: int64

# %%
#Unique workclass value

data['workclass'].unique()
# Out:
# array([' State-gov', ' Self-emp-not-inc', ' Private', ' Federal-gov',
#        ' Local-gov', ' ?', ' Self-emp-inc', ' Without-pay',
#        ' Never-worked'], dtype=object)

# %%
data.replace(' ?','Unknown',inplace=True)

# %%
data['workclass'].unique()
# Out:
# array([' State-gov', ' Self-emp-not-inc', ' Private', ' Federal-gov',
#        ' Local-gov', 'Unknown', ' Self-emp-inc', ' Without-pay',
#        ' Never-worked'], dtype=object)

# %%
#Plot the count plot using the workclass

sns.countplot(data['workclass'])
plt.xticks(rotation = 90)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Create a countplot of workclass based on salary

sns.countplot(data['workclass'], hue = data['salary'])
plt.xticks(rotation = 90)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.scatterplot(data['workclass'], hue = data['salary'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Types of educational values

data['education'].value_counts()
# Out:
#  HS-grad         10501
#  Some-college     7291
#  Bachelors        5355
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           333
#  1st-4th           168
#  Preschool          51
# Name: education, dtype: int64

# %%
data['education'].nunique()
# Out:
# 16

# %%
data['education-num'].nunique()
# Out:
# 16

# %%
data[data['education']==' Bachelors']
# Out:
#        age          workclass  fnlwgt  ... hours-per-week         country  salary
# 0       39          State-gov   77516  ...             40   United-States   <=50K
# 1       50   Self-emp-not-inc   83311  ...             13   United-States   <=50K
# 4       28            Private  338409  ...             40            Cuba   <=50K
# 9       42            Private  159449  ...             40   United-States    >50K
# 11      30          State-gov  141297  ...             40           India    >50K
# ...    ...                ...     ...  ...            ...             ...     ...
# 32530   35                  ?  320084  ...             55   United-States    >50K
# 32531   30                  ?   33811  ...             99   United-States   <=50K
# 32533   54            Private  337992  ...             50           Japan    >50K
# 32536   34            Private  160216  ...             55   United-States    >50K
# 32538   38            Private  139180  ...             45   United-States    >50K
#
# [5355 rows x 15 columns]

# %%
data[data['education']==' HS-grad']
# Out:
#        age          workclass  fnlwgt  ... hours-per-week         country  salary
# 2       38            Private  215646  ...             40   United-States   <=50K
# 7       52   Self-emp-not-inc  209642  ...             45   United-States    >50K
# 16      25   Self-emp-not-inc  176756  ...             35   United-States   <=50K
# 17      32            Private  186824  ...             40   United-States   <=50K
# 21      54            Private  302146  ...             20   United-States   <=50K
# ...    ...                ...     ...  ...            ...             ...     ...
# 32547   43            Private  260761  ...             40          Mexico   <=50K
# 32557   40            Private  154374  ...             40   United-States    >50K
# 32558   58            Private  151910  ...             40   United-States   <=50K
# 32559   22            Private  201490  ...             20   United-States   <=50K
# 32560   52       Self-emp-inc  287927  ...             40   United-States    >50K
#
# [10501 rows x 15 columns]

# %%
#Drop the columns which are not required

data.drop(['education','capital-loss', 'capital-gain'],axis=1,inplace=True)

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education-num', 'marital-status',
#        'occupation', 'relationship', 'race', 'sex', 'hours-per-week',
#        'country', 'salary'],
#       dtype='object')

# %%
data['marital-status'].unique()
# Out:
# array([' Never-married', ' Married-civ-spouse', ' Divorced',
#        ' Married-spouse-absent', ' Separated', ' Married-AF-spouse',
#        ' Widowed'], dtype=object)

# %%
data['occupation'].unique()
# Out:
# array([' Adm-clerical', ' Exec-managerial', ' Handlers-cleaners',
#        ' Prof-specialty', ' Other-service', ' Sales', ' Craft-repair',
#        ' Transport-moving', ' Farming-fishing', ' Machine-op-inspct',
#        ' Tech-support', ' ?', ' Protective-serv', ' Armed-Forces',
#        ' Priv-house-serv'], dtype=object)

# %%
data.replace(' ?','Unknown',inplace=True)

# %%
data['occupation'].unique()
# Out:
# array([' Adm-clerical', ' Exec-managerial', ' Handlers-cleaners',
#        ' Prof-specialty', ' Other-service', ' Sales', ' Craft-repair',
#        ' Transport-moving', ' Farming-fishing', ' Machine-op-inspct',
#        ' Tech-support', 'Unknown', ' Protective-serv', ' Armed-Forces',
#        ' Priv-house-serv'], dtype=object)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education-num   32561 non-null  int64
#  4   marital-status  32561 non-null  object
#  5   occupation      32561 non-null  object
#  6   relationship    32561 non-null  object
#  7   race            32561 non-null  object
#  8   sex             32561 non-null  object
#  9   hours-per-week  32561 non-null  int64
#  10  country         32561 non-null  object
#  11  salary          32561 non-null  object
# dtypes: int64(4), object(8)
# memory usage: 3.0+ MB

# %%
cat_cols = ['workclass', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'country']

df = pd.get_dummies(data[cat_cols], drop_first= True)

# %%
data.drop(cat_cols, axis = 1, inplace = True)

# %%
data
# Out:
#        age  fnlwgt  education-num  hours-per-week  salary
# 0       39   77516             13              40   <=50K
# 1       50   83311             13              13   <=50K
# 2       38  215646              9              40   <=50K
# 3       53  234721              7              40   <=50K
# 4       28  338409             13              40   <=50K
# ...    ...     ...            ...             ...     ...
# 32556   27  257302             12              38   <=50K
# 32557   40  154374              9              40    >50K
# 32558   58  151910              9              40   <=50K
# 32559   22  201490              9              20   <=50K
# 32560   52  287927              9              40    >50K
#
# [32561 rows x 5 columns]

# %%
data['salary'] = data['salary'].map({" <=50K" : 0,
                                    " >50K" : 1})

# %%
data['salary'].unique()
# Out:
# array([0, 1])

# %%
data
# Out:
#        age  fnlwgt  education-num  hours-per-week  salary
# 0       39   77516             13              40       0
# 1       50   83311             13              13       0
# 2       38  215646              9              40       0
# 3       53  234721              7              40       0
# 4       28  338409             13              40       0
# ...    ...     ...            ...             ...     ...
# 32556   27  257302             12              38       0
# 32557   40  154374              9              40       1
# 32558   58  151910              9              40       0
# 32559   22  201490              9              20       0
# 32560   52  287927              9              40       1
#
# [32561 rows x 5 columns]

# %%
new_data = pd.concat([df, data], axis = 1)

# %%
new_data.head()
# Out:
#    workclass_ Local-gov  workclass_ Never-worked  ...  hours-per-week  salary
# 0                     0                        0  ...              40       0
# 1                     0                        0  ...              13       0
# 2                     0                        0  ...              40       0
# 3                     0                        0  ...              40       0
# 4                     0                        0  ...              40       0
#
# [5 rows x 84 columns]

# %%
#Seperate x and y variables

x = new_data.drop('salary', axis = 1)

y = new_data['salary']

# %%
#Split dataset into training and testing

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.25, random_state = 0)

# %%
#Import random forest classifier from ensembles

from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier(n_estimators = 150)
rf_model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=150,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
#Training prediction 

tr_predict = rf_model.predict(x_train)

# %%
ts_predict = rf_model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, plot_confusion_matrix, roc_auc_score

print("Training accuracy", accuracy_score(y_train, tr_predict))
print("Test Accuracy", accuracy_score(y_test, ts_predict))
# Out:
# Training accuracy 0.9999590499590499
# Test Accuracy 0.826311263972485

# %%
#Change the estimators

train_acc = []
test_acc = []

for n in range(100, 500, 100):
  rf_model = RandomForestClassifier(n_estimators= n)
  rf_model.fit(x_train, y_train)

  tr_predict = rf_model.predict(x_train)
  train_acc.append(accuracy_score(y_train, tr_predict))

  ts_predict =  rf_model.predict(x_test)
  test_acc.append(accuracy_score(y_test, ts_predict))

# %%
n_estimators = [x for x in range(100,500,100)]
n_estimators
# Out:
# [100, 200, 300, 400]

# %%
plt.plot(n_estimators, train_acc)
plt.plot(n_estimators, test_acc)

plt.show()
